# %% [markdown]
# #### Max_Length
# Since there are 5 captions for each image and we have preprocessed and encoded them in below format
#
# "startseq " + caption + " endseq"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pickle import load,dump
from numpy import array

# %%
# load the saved dictionary
with open("descriptions.pkl","rb") as f:
    descriptions = load(f)

# %%
descriptions["2394267183_735d2dc868"]
# Out:
# ['startseq a dog goes through an obstacle course while a person looks on  endseq',
#  'startseq a dog is going through a slalom style obstacle course  endseq',
#  'startseq a dog performs a slalom like obstacle while the owner walks along side  endseq',
#  'startseq a dog plays with a man by running around poles  endseq',
#  'startseq the woman is training a white dog to zigzag through metal poles  endseq']

# %%
# train descriptions dictionary creation
train_descriptions = dict()
with open("data/Flickr8k_text/Flickr_8k.trainImages.txt","r") as f:
    data = f.read()
    
try:
    for el in data.split("\n"):
        tokens = el.split(".")
        image_id = tokens[0]
        if image_id in descriptions:
            train_descriptions[image_id] = descriptions[image_id]
                    
except Exception as e:
    print("Exception got :- \n",e)

# %%
#save the file
dump(train_descriptions,open("train_descriptions.pkl","wb"))

# %% [markdown]
# Vocablury Preparation

# %%
from nltk import FreqDist

# %%
# creating corpus
corpus = ""

with open("train_descriptions.pkl","rb") as f:
    train_descriptions = load(f)
for ec in train_descriptions.values():
    for el in ec:
        corpus += " "+el

# %%
total_words = corpus.split()
vocabulary = set(total_words)
print("The size of vocablury is {}".format(len(vocabulary)))
# Out:
# The size of vocablury is 7373

# %%
# creating frequecny distribution of words
freq_dist = FreqDist(total_words)
freq_dist.most_common(5)
# Out:
# [('a', 46784),
#  ('startseq', 30000),
#  ('endseq', 30000),
#  ('in', 14094),
#  ('the', 13509)]

# %%
#removing least common words from vocabulary
for ew in list(vocabulary):
    if(freq_dist[ew]<10):
        vocabulary.remove(ew)

# %%
VOCAB_SIZE = len(vocabulary)+1
print("Total unique words after remooving less frequent word from our corpus = {}".format(VOCAB_SIZE))
# Out:
# Total unique words after remooving less frequent word from our corpus = 1665

# %%
train_descriptions
# Out:
# {'2513260012_03d33305cf': ['startseq a black dog is running after a white dog in the snow  endseq',
#   'startseq black dog chasing brown dog through snow endseq',
#   'startseq two dogs chase each other across the snowy ground  endseq',
#   'startseq two dogs play together in the snow  endseq',
#   'startseq two dogs running through a low lying body of water  endseq'],
#  '2903617548_d3e38d7f88': ['startseq a little baby plays croquet  endseq',
#   'startseq a little girl plays croquet next to a truck  endseq',
#   'startseq the child is playing croquette by the truck  endseq',
#   'startseq the kid is in front of a car with a put and a ball  endseq',
#   'startseq the little boy is playing with a croquet hammer and ball beside the car  endseq'],
#  '3338291921_fe7ae0c8f8': ['startseq a brown dog in the snow has something hot pink in its mouth  endseq',
#   'startseq a brown dog in the snow holding a pink hat  endseq',
#   'startseq a brown dog is holding a pink shirt in the snow  endseq',
#   'startseq a dog is carrying something pink in its mouth while walking through the snow  endseq',
#   'startseq a dog with something pink in its mouth is looking forward  endseq'],
#  '488416045_1c6d903fe0': ['startseq a brown dog is running along a beach  endseq',
#   'startseq a brown dog wearing a black collar running across the beach  endseq',
#   'startseq a dog walks on the sand near the water  endseq',
#   'startseq brown dog running on the beach  endseq',
#   'startseq the large brown dog is running on the beach by the ocean  endseq'],
#  '2644326817_8f45080b87': ['startseq a black and white dog with a red frisbee standing on a sandy beach  endseq',
#   'startseq a dog drops a red disc on a beach  endseq',
#   'startseq a dog with a red frisbee flying in the air  endseq',
#   'startseq dog catching a red frisbee  endseq',
#   'startseq the black dog is dropping a red disc on a beach  endseq'],
#  '218342358_1755a9cce1': ['startseq a cyclist wearing a red helmet is riding on the pavement  endseq',
#   'startseq a girl is riding a bike on the street while wearing a red helmet  endseq',
#   'startseq a person on a bike wearing a red helmet riding down a street  endseq',
#   'startseq a woman wears a red helmet and blue shirt as she goes for a bike ride in the shade  endseq',
#   'startseq person in blue shirt and red helmet riding bike down the road endseq'],
#  '2501968935_02f2cd8079': ['startseq a man dressed in a purple shirt and red bandanna smiles at the people watching him  endseq',
#   'startseq a man on the street wearing leather chaps and a chainmail codpiece  endseq',
#   'startseq a man wearing a purple shirt and black leather chaps poses for the camera  endseq',
#   'startseq man dressed in leather chaps and purple shirt stands in front of onlookers endseq',
#   'startseq there is a man in a purple shirt leather chaps and a red bandanna standing near other men  endseq'],
#  '2699342860_5288e203ea': ['startseq a boy wearing a red t shirt is running through woodland  endseq',
#   'startseq a child runs near some trees  endseq',
#   'startseq a young boy is dancing around  endseq',
#   'startseq a young boy with a red short sleeved shirt and jeans runs by some trees  endseq',
#   'startseq the little boy in the red shirt stops to smile for the camera  endseq'],
#  '2638369467_8fc251595b': ['startseq a girl in a white dress  endseq',
#   'startseq a little girl in white is looking back at the camera while carrying a water grenade  endseq',
#   'startseq a smiling young girl in braids is playing ball  endseq',
#   'startseq a young girl wearing white looks at the camera as she plays  endseq',
#   'startseq the girl is holding a green ball  endseq'],
#  '2926786902_815a99a154': ['startseq a skier in a yellow jacket is airborne above the mountains  endseq',
#   'startseq a skier jumps high in the air with a view of the mountains  endseq',
#   'startseq a skiing man in a fluorescent jacket jumps very high and it looks as though he is flying  endseq',
#   'startseq somone is high in the air doing a ski jump  endseq',
#   'startseq the skier in the green jacket and white pants appears to almost fly into the sky  endseq'],
#  '2851304910_b5721199bc': ['startseq a photographer looks over the hills  endseq',
#   'startseq a woman in a red jacket is videotaping a natural landscape  endseq',
#   'startseq a woman with a camera looks out over rolling hills  endseq',
#   'startseq a woman with a camera on a tripod is looking at the view  endseq',
#   'startseq lady in red shirt has her camera set up in the field to record something  endseq'],
#  '3423802527_94bd2b23b0': ['startseq a bunch of girls in cheerleader outfits  endseq',
#   'startseq a large group of cheerleaders walking in a parade endseq',
#   'startseq cheerleaders perform  endseq',
#   'startseq many cheerleaders wearing black walk down the street  endseq',
#   'startseq parade of cheerleaders wearing black pink and white uniforms  endseq'],
#  '3356369156_074750c6cc': ['startseq a blue boat with a yellow canopy is floating on calm waters  endseq',
#   'startseq a boat in the water  endseq',
#   'startseq a boat with a roof on green water  endseq',
#   'startseq the boat is in the middle of the water  endseq',
#   'startseq the solitude boat floats on the lake  endseq'],
#  '2294598473_40637b5c04': ['startseq a dog catches a frisbee in midair  endseq',
#   'startseq a dog catching a frisbee  endseq',
#   'startseq a terrier mix catches a frisbee in the air  endseq',
#   'startseq a white and black dog catching a frisbee  endseq',
#   'startseq a white dog is leaping in the air with a green object in its mouth  endseq'],
#  '1191338263_a4fa073154': ['startseq a little old lady sitting next to an advertisement  endseq',
#   'startseq an asian woman waiting at an underground train stop  endseq',
#   'startseq an old woman sits in a transit station next to a backlit advertisement  endseq',
#   'startseq a woman sits in a subway station  endseq',
#   'startseq a woman with an umbrella is sitting at a station with an aquos commercial on the wall  endseq'],
#  '2380765956_6313d8cae3': ['startseq a blond girl wearing a green jacket walks on a trail along side a metal fence  endseq',
#   'startseq a girl in a green coat walks down a rural road playing a flute endseq',
#   'startseq a young girl in a parka playing a flute while walking by a fenced in field  endseq',
#   'startseq girl in green and blue jacket walking past an enclosed field  endseq',
#   'startseq girl playing flute as she walks by fence in rural area  endseq'],
#  '3197891333_b1b0fd1702': ['startseq a family of nine people including four children pose in front of a brick fireplace with a white mantle  endseq',
#   'startseq a family poses in front of the fireplace and christmas tree  endseq',
#   'startseq a family posing by the mantle and christmas tree  endseq',
#   'startseq a happy family poses by the fireplace  endseq',
#   'startseq two couples and four kids pose for a family picture  endseq'],
#  '3119887967_271a097464': ['startseq man in a sweater pointing at the camera  endseq',
#   'startseq one man is posing with arms outstretched and finger pointed while another stares from behind him  endseq',
#   'startseq the man in the black hat stands behind the man who is pointing his finger  endseq',
#   'startseq two men look toward the camera while the one in front points his index finger  endseq',
#   'startseq two men one wearing a black hat while the one in front points standing in a hallway  endseq'],
#  '2276499757_b44dc6f8ce': ['startseq a dog looks warily at the brown dog investigating his area  endseq',
#   'startseq a large brown dog is looking at a medium sized black dog  endseq',
#   'startseq a small black dog looks at a larger brown dog in a grassy field  endseq',
#   'startseq the big brown dog looks at the small black dog in tall grass  endseq',
#   'startseq there is a big dog looking at a little dog  endseq'],
#  '2506892928_7e79bec613': ['startseq three children in a field with white flowers endseq',
#   'startseq three children one with a stuffed kitten in a field of flowers  endseq',
#   'startseq three children play in the garden  endseq',
#   'startseq three children pose among wildflowers  endseq',
#   'startseq three kids palying with a toy cat in a garden  endseq'],
#  '2187222896_c206d63396': ['startseq a boy in a red shirt in front of a long blue wall raises his eyebrow at the camera endseq',
#   'startseq a boy in a red shirt with stripes standing near a blue brick wall with handicap signs  endseq',
#   'startseq an african american boy stands in front of a blue building in the handicapped space  endseq',
#   'startseq the boy in the orange shirt looks backwards  endseq',
#   'startseq the boy in the red shirt is next to a blue wall  endseq'],
#  '2826769554_85c90864c9': ['startseq a brown dog is carrying a wet stick on the shore of the ocean  endseq',
#   'startseq a dog bounds across the sandy beach with a stick in his mouth and water splashing off his paws  endseq',
#   'startseq a wet blond dog carries a stick on the shore  endseq',
#   'startseq the dog is running along the beach next to the ocean with a stick in its mouth  endseq',
#   'startseq the wet brown dog has a stick in his mouth and is running in the sand next to the water  endseq'],
#  '3097196395_ec06075389': ['startseq two dogs are racing on a ractrack  endseq',
#   'startseq two dogs race across the track  endseq',
#   'startseq two greyhounds race endseq',
#   'startseq two greyhounds with muzzles race along the inside curb of a railed dirt track  endseq',
#   'startseq two racing dogs run around a track  endseq'],
#  '3603116579_4a28a932e2': ['startseq a baseball pitcher with shelton on his shirt throws the ball  endseq',
#   'startseq a baseball player in a black and orange shirt and with a glove on pitches the ball  endseq',
#   'startseq a male dressed in a sports outfit tries to catch a baseball  endseq',
#   'startseq a man playing baseball  endseq',
#   'startseq the baseball player is running after the ball  endseq'],
#  '3339263085_6db9fd0981': ['startseq a brown dog wades through water and walks toward a rock  endseq',
#   'startseq a dog has waded through shallow water to reach a rock outcropping  endseq',
#   'startseq a light brown dog is splashing in the water with its paw  endseq',
#   'startseq a small brown dog is about ready to exit the water after a swim  endseq',
#   'startseq a yellow dog in shallow water  endseq'],
#  '2532262109_87429a2cae': ['startseq a group of 5 girls in school uniforms are standing together and waiting to cross the street while one girl takes a picture  endseq',
#   'startseq a group of people are standing together outside as one takes a photograph  endseq',
#   'startseq a group of school girls are standing together while one is taking pictures  endseq',
#   'startseq a group of young women stand together  endseq',
#   'startseq girls in school uniforms  endseq'],
#  '2076906555_c20dc082db': ['startseq a boy wearing a jean jacket with his hand on his chest smiling at the camera  endseq',
#   'startseq a boy with a bruised nose and writing on his hands is standing in a video rental store  endseq',
#   'startseq a boy with writing on his hand is standing in a store  endseq',
#   'startseq a young man in a jean jacket smiles for the camera inside a store  endseq',
#   'startseq a young man with a denim jacket and writing on his hand smiles in front of a bookcase full of videos  endseq'],
#  '2502007071_82a8c639cf': ['startseq a group of people in front of a house  endseq',
#   'startseq a man in stripes a woman in sunglasses and a child in a blue hat in front of a brick building  endseq',
#   'startseq a woman in sunglasses and a blue flowered shirt stands while a boy and a man sit nearby  endseq',
#   'startseq a woman wearing sunglasses and a flowered shirt looks to the left  endseq',
#   'startseq three adults and one child are waiting outside of a building perhaps a school  endseq'],
#  '3113769557_9edbb8275c': ['startseq a woman stands in front of a display case and another woman looks at a digital camera endseq',
#   'startseq a woman stands tall in front of a glass display while another woman takes a picture of something  endseq',
#   'startseq a woman stands with her arms out at her sides while another takes a picture  endseq',
#   'startseq a woman stands with her arms out in a store while another woman holds a camera  endseq',
#   'startseq one woman is taking a picture and another woman is standing sideways with her arm out  endseq'],
#  '3325974730_3ee192e4ff': ['startseq a snowboarder jumps high into the air off of a snowy ramp  endseq',
#   'startseq a snowboarder jumps off a ramp  endseq',
#   'startseq man on a snowboard performing a trick high in the air  endseq',
#   'startseq person in a purple coat making a jump on a snowboard  endseq',
#   'startseq snowboarder jumps off high ramp over icy landscape  endseq'],
#  '1655781989_b15ab4cbff': ['startseq a group of mountain climbers endseq',
#   'startseq a group of people walking in a line through the snow toward a mountain  endseq',
#   'startseq a line of people are making their way through snow covered mountains  endseq',
#   'startseq people are walking through a snow covered field with a mountain the background  endseq',
#   'startseq people facing mountains in the snow  endseq'],
#  '1662261486_db967930de': ['startseq a black and white dog is jumping through a black and white hoop  endseq',
#   'startseq a black and white dog jumps through a black and white hoop  endseq',
#   'startseq a brown and white dog jumping through a black and white hoop  endseq',
#   'startseq a dog jumping through a black and white hoop  endseq',
#   'startseq a dog jumping through a ring  endseq'],
#  '2410562803_56ec09f41c': ['startseq a girl using a laptop another girl and a boy looking at his cellphone  endseq',
#   'startseq a group of people sit against a building and use electronics  endseq',
#   'startseq three people sit near a street  endseq',
#   'startseq three people sitting in front of a store on a bench  endseq',
#   'startseq three young people sit outside and engage with electronic devices  endseq'],
#  '2469498117_b4543e1460': ['startseq a dog races while wearing number 6  endseq',
#   'startseq a greyhound wearing a muzzle and the number six on a yellow jacket is running on a dog track  endseq',
#   'startseq a muzzle greyhound dog running on a track endseq',
#   'startseq a tan greyhound wearing a gold shirt with a number on it runs down a track  endseq',
#   'startseq muxzzled greyhound leaping in race with yellow jacket  endseq'],
#  '69710415_5c2bfb1058': ['startseq a group of people stand at the edge of a cliff over the ocean  endseq',
#   'startseq a group of three boy scouts rest on a bluff overlooking the ocean  endseq',
#   'startseq three men stand on a cliff overlooking a lake  endseq',
#   'startseq three scouts are on top of a cliff overlooking the ocean  endseq',
#   'startseq two men are sitting on a rock near the ocean with another man standing nearby  endseq'],
#  '3414734842_beb543f400': ['startseq a couple holding hands and another woman are walking down a wooded trail  endseq',
#   'startseq a couple holding hands and a woman standing beside them pose on a tree lined dirt road  endseq',
#   'startseq three friends on a stroll in the forest  endseq',
#   'startseq three people stand on a path through the woods  endseq',
#   'startseq two women and a man posing on a rural path endseq'],
#  '3006217970_90b42e6b27': ['startseq a car sponsored by riwal is smoking its tires on a wet road  endseq',
#   'startseq a race car drives along a track in the rain endseq',
#   'startseq a racing car is driving around a wet track with its headlights on  endseq',
#   'startseq a small race car with advertising is driving on a rainy track  endseq',
#   'startseq a sponsored race car is driving with lights on a wet raceway  endseq'],
#  '2192411521_9c7e488c5e': ['startseq a bearded man wearing a bandanna is pointing his finger whilst riding a bicycle  endseq',
#   'startseq a man bicycles down the street and points his finger endseq',
#   'startseq a man holds an object with his hand while riding his bike down the street  endseq',
#   'startseq a man with long hair riding a bicycle gives the peace sign  endseq',
#   'startseq man in blue shirt and black cap riding bike down street flashing peace sign endseq'],
#  '3535879138_9281dc83d5': ['startseq a crowd of people waving red flags are passing under a bridge  endseq',
#   'startseq a group of people walk down the street carrying red flags  endseq',
#   'startseq a large group of people walking down a street some carrying flags or banners  endseq',
#   'startseq many people walking together on pavement near a brick building with other people looking on  endseq',
#   'startseq many people walk in the street  endseq'],
#  '2685788323_ceab14534a': ['startseq a man in sunglasses gets ready to pull a chair out to sit down for his meal  endseq',
#   'startseq a man wearing sunglasses stands by a table at a cafe  endseq',
#   'startseq man about to pull out chair and sit down at a restaurant  endseq',
#   'startseq man at eatery getting ready to sit down  endseq',
#   'startseq the large man grabs a seat at a restaurant  endseq'],
#  '3465606652_f380a38050': ['startseq a boy holding a racket is standing in the grass  endseq',
#   'startseq a boy in a purple shirt and blue jeans is standing in the grass holding a round toy with a handle  endseq',
#   'startseq a boy playes with a stringless racket in his backyard  endseq',
#   'startseq a boy walks through the lawn  endseq',
#   'startseq a child in purple clothing is playing with a toy inside a yard with other toys and a fence  endseq'],
#  '2599131872_65789d86d5': ['startseq two blond girls are playing together  endseq',
#   'startseq two girls enjoy themselves whilst wind blows through their hair  endseq',
#   'startseq two girls with long hair jumping on a trampoline  endseq',
#   'startseq two little blonde girls twirl their hair  endseq',
#   'startseq two little girls are playing on a trampoline  endseq'],
#  '2244613488_4d1f9edb33': ['startseq four bicyclists ride along a dirt road between two wire fences  endseq',
#   'startseq four cyclists on a country trail are passing by an electricity pylon  endseq',
#   'startseq the four bicyclists are riding through the desert  endseq',
#   'startseq three bikers bike across the dry land  endseq',
#   'startseq three cyclists ride near mountain  endseq'],
#  '2738077433_10e6264b6f': ['startseq a dog climbing a steep dirt hill  endseq',
#   'startseq a dog climbs a hill  endseq',
#   'startseq a great dane climbing a steep hill endseq',
#   'startseq a light brown dog is running up  endseq',
#   'startseq a light dog climbing a wall of dirt  endseq'],
#  '3537201804_ce07aff237': ['startseq a child spins on a merry go round  endseq',
#   'startseq childern are playing on a merry go round as adults on a bench watch them  endseq',
#   'startseq children play on a merry go round as adults look on from a bench  endseq',
#   'startseq fathers watch as their children enjoy the spinning merry go round  endseq',
#   'startseq two kids sit in the middle of a playground toy that spins around them  endseq'],
#  '1597557856_30640e0b43': ['startseq a brown dog is jumping up at a woman who is wearing a brown skirt  endseq',
#   'startseq a golden retriever is excitedly greeting a woman as a little dog walks towards the camera  endseq',
#   'startseq a tan dog jumping up at a woman in a skirt and a black and tan dog walking away  endseq',
#   'startseq a yellow dog jumps to greet a woman  endseq',
#   'startseq one dog is jumping at the lady while the other walks away  endseq'],
#  '3357194782_c261bb6cbf': ['startseq a man in the dooorway of a bus looking onward  endseq',
#   'startseq a man standing at the door of a vehicle with another sitting glancing out the window  endseq',
#   'startseq people ride a bus or trolley  endseq',
#   'startseq some people riding an old bus endseq',
#   'startseq three passengers on a train car  endseq'],
#  '3682038869_585075b5ff': ['startseq a little girl is peaking out from behind a tree  endseq',
#   'startseq a little girl peering out from behind a tree  endseq',
#   'startseq a young girl hiding behind a tree in a forest  endseq',
#   'startseq a young girl peeking out from behind a tree in a wooded area  endseq',
#   'startseq a young girl wearing a striped dress peeks out from behind a tree  endseq'],
#  '236474697_0c73dd5d8b': ['startseq a group of people hold drinks and point at the camera  endseq',
#   'startseq a group of people are holding up drinks and pointing to the camera  endseq',
#   'startseq a group of young people holding bottles and pointing at the camera  endseq',
#   'startseq several young people posing for this photo holding beers endseq',
#   'startseq young adults stand pointing at the person taking the picture  endseq'],
#  '2641288004_30ce961211': ['startseq a border collie jumps over a bed with a tennis ball in its mouth  endseq',
#   'startseq a dog jumping with a ball in its mouth  endseq',
#   'startseq a dog jumps on a bed and catches a green toy  endseq',
#   'startseq border collie jumps in the air and catches a tennis ball  endseq',
#   'startseq the black and white dog jumps with a tennis ball in its mouth  endseq'],
#  '267164457_2e8b4d30aa': ['startseq a climber walks along a snowy peak  endseq',
#   'startseq a man climbs over snow covered rocks by a shore  endseq',
#   'startseq a man is standing on a snowcapped mountain  endseq',
#   'startseq a person hikes down a snowy mountain  endseq',
#   'startseq there man on top of an snow covered mountain with a lake behind him  endseq'],
#  '2453891449_fedb277908': ['startseq a white dog chasing a black dog across the grass  endseq',
#   'startseq a white dog is following a black dog through the grassy area  endseq',
#   'startseq there are two dogs black and white and the black one is jumping  endseq',
#   'startseq two dogs running in a grassy fenced in area surrounded by trees  endseq',
#   'startseq two dogs running through a yard with a forest in the distance  endseq'],
#  '281419391_522557ce27': ['startseq a black race car spins its tires while smoke comes out  endseq',
#   'startseq a black race car starts up in front of a crowd of people  endseq',
#   'startseq a broken down car during a race endseq',
#   'startseq race car smoking very badly on the racetrack  endseq',
#   'startseq red bull branded race car leaves smoke behind it in front of a crowd  endseq'],
#  '354999632_915ea81e53': ['startseq a person behind some bags inside an igloo  endseq',
#   'startseq a snowy cave full of luggage endseq',
#   'startseq inside the igloo the young man gets ready for his overnight stay  endseq',
#   'startseq some backpacks piled up in an ice cave with a person dressed in black in the background  endseq',
#   'startseq there is something visible through the hole in the wall  endseq'],
#  '3109136206_f7d201b368': ['startseq a brown dog drinks from a body of water  endseq',
#   'startseq a brown dog is starting to walk into water  endseq',
#   'startseq a brown dog steps into murky water  endseq',
#   'startseq a dog getting into some water  endseq',
#   'startseq a dog putting his legs into a pond endseq'],
#  '2281054343_95d6d3b882': ['startseq a man wearing a black hat is walking through a busy city street  endseq',
#   'startseq a silhouette of a man in a hat on a busy city street  endseq',
#   'startseq person with black hat and black coat near buildings with signs  endseq',
#   'startseq three people in a crowded city area  endseq',
#   'startseq thre is a shot of man with his back turned in a city  endseq'],
#  '3296584432_bef3c965a3': ['startseq a brown dog chases something a man behind him threw on the beach  endseq',
#   'startseq a man and a dog on the beach  endseq',
#   'startseq a man is interacting with a dog that is running in the opposite direction  endseq',
#   'startseq a man playing fetch with his dog on a beach  endseq',
#   'startseq a man walking behind a running dog on the beach  endseq'],
#  '3526431764_056d2c61dc': ['startseq a woman taking a photo standing next to a tall man and in front of another man who is also taking a photo  endseq',
#   'startseq three people are outdoors taking pictures  endseq',
#   'startseq three people holding cameras are standing on a dirt trail with grass on the side of it  endseq',
#   'startseq three people taking pictures with their cameras endseq',
#   'startseq two people are taking pictures while a third is holding a camera  endseq'],
#  '3549997413_01388dece0': ['startseq a man is skiing down a mountain with another large mountain behind him and a river between the mountains  endseq',
#   'startseq a man is skiing down a snowy hill with a large mountain in the background  endseq',
#   'startseq a man skiing down a snow covered mountain  endseq',
#   'startseq a person skis down a snowy mountain  endseq',
#   'startseq a skier goes down a hill with a mountain as a backdrop  endseq'],
#  '143688895_e837c3bc76': ['startseq a boy climbing a rock face endseq',
#   'startseq a climber is standing on the rock face next to the pink rope  endseq',
#   'startseq a man climbing a cliff with a rope  endseq',
#   'startseq a man climbs steep rocks  endseq',
#   'startseq a man rock climbing in the forest surrounded by light  endseq'],
#  '2495394666_2ef6c37519': ['startseq a brown dog is standing in a lake  endseq',
#   'startseq a brown dog is swimming in a creek  endseq',
#   'startseq a dog swimming in a pond endseq',
#   'startseq dog swimming in body of water endseq',
#   'startseq the brown dog is swimming in the water  endseq'],
#  '3384742888_85230c34d5': ['startseq a dog plays with a toy in the grass  endseq',
#   'startseq a rotweiler playfully rolls over int he grass with a toy  endseq',
#   'startseq black and tan dog playing with a toy and rolling on the grass  endseq',
#   'startseq dog chewing up ball while rolling in grass endseq',
#   'startseq the dog is resting after a game of fetch  endseq'],
#  '1160034462_16b38174fe': ['startseq a elderly man in a straw hat is sitting on a bench  endseq',
#   'startseq a elderly man sits alone on a park bench  endseq',
#   'startseq an old man in a straw hat sits on a park bench  endseq',
#   'startseq the old man in the brown hat is sitting on the bench  endseq',
#   'startseq white haired man in gray sweater and a straw hat sitting on a bench under a tree  endseq'],
#  '334768700_51c439b9ee': ['startseq a dark haired man in a red t shirt with a beard playing the guitar in a park  endseq',
#   'startseq a man in a red shirt plays guitar in a park  endseq',
#   'startseq a man is sitting and playing guitar on the grass  endseq',
#   'startseq a man sitting in the grass playing his guitar wearing a red shirt endseq',
#   'startseq a man wearing red plays his guitar on the grass  endseq'],
#  '412101267_7257e6d8c0': ['startseq two black dogs are jumping and playing with a yellow tennis ball in the snow  endseq',
#   'startseq two dog play in the snow  endseq',
#   'startseq two dogs one with a tennis ball in his mouth play together in the snow  endseq',
#   'startseq two dogs playing with a ball in the snow  endseq',
#   'startseq two dogs play with a tennis ball in the snow  endseq'],
#  '2623939135_0cd02ffa5d': ['startseq an attractive woman holds a halo above her head  endseq',
#   'startseq a woman in a dress raises her arm over her head  endseq',
#   'startseq a woman is looking at the ceiling while taking off her hat  endseq',
#   'startseq a woman looking up towards a wide ring she is holding over her head a drink in her other hand  endseq',
#   'startseq a woman looking upward with her hand above her head  endseq'],
#  '3043266735_904dda6ded': ['startseq an elderly person with a white hat is reading a paperback book  endseq',
#   'startseq an elder woman in a hat and scarf is looking through a book she has in her hands  endseq',
#   'startseq an older woman wearing a hat reads a book  endseq',
#   'startseq an old lady consulting a paperback book  endseq',
#   'startseq a woman in a white hat reading a book  endseq'],
#  '3034585889_388d6ffcc0': ['startseq a looker on catches a motocross bike on its side after a spill while another races by  endseq',
#   'startseq a man on a dirt bike zipping away while another one slips to the ground and a third man in a yellow jacket looks on  endseq',
#   'startseq a man on a motorcycle making a tight turn endseq',
#   'startseq a person is riding their motorbike and a person in a bright yellow jacket is watching someone fall off their bike  endseq',
#   'startseq bike rider is looking at a accident of other sports bike rider  endseq'],
#  '2069279767_fb32bfb2de': ['startseq the men are climbing  endseq',
#   'startseq two men are lying in red cots on the side of a mountain  endseq',
#   'startseq two men are sleeping on makeshift beds on the side of a cliff  endseq',
#   'startseq two men in cots hanging from a cliff endseq',
#   'startseq two mountain climbers are smiling on the mountainside  endseq'],
#  '2593406865_ab98490c1f': ['startseq a skateboarder jumps off his skateboard in midair in hopes of landing back on it  endseq',
#   'startseq a teenage boy is performing a trick with his skateboard  endseq',
#   'startseq a young man is flipping a skateboard during a trick  endseq',
#   'startseq a young skateboarder doing tricks in the air endseq',
#   'startseq the man is performing a trick on a skateboard near onlookers  endseq'],
#  '432167214_c17fcc1a2d': ['startseq a dark colored man is holding a protest banner in a busy city street with people staring from behind  endseq',
#   'startseq a man in a blue and yellow jacket holding a religious sign stands in a street with people behind him on the sidewalk  endseq',
#   'startseq a man is holding a religious poster  endseq',
#   'startseq a man wearing a hat holding a sign with writing on it  endseq',
#   'startseq man standing on the street holding a sign endseq'],
#  '305749904_54a612fd1a': ['startseq a man is wearing a blue shirt with the word mambo on it  endseq',
#   'startseq a man is wearing a shirt that reads mambo with an image of a baby and a teddy bear  endseq',
#   'startseq a man wears a t shirt showing a baby humping a stuffed bear  endseq',
#   'startseq a person wearing a blue mambo shirt has his back to the camera  endseq',
#   'startseq the man is wearing a blue shirt  endseq'],
#  '2780087302_6a77658cbf': ['startseq a man in black shirt sits on a stool while trying to sell stuffed animals  endseq',
#   'startseq a man is outside selling various toys  endseq',
#   'startseq a vendor sells children is toys as visitors walk by  endseq',
#   'startseq a vendor sells inflatable toys and stuffed animals on the sidewalk  endseq',
#   'startseq man sits on stool beside toys  endseq'],
#  '3051998298_38da5746fa': ['startseq a guy in navy blue and yellow shorts jumping into a pool  endseq',
#   'startseq a man catches a football in midair while jumping into a pool  endseq',
#   'startseq a man in swim trunks is jumping into a pool while in a strange pose endseq',
#   'startseq antics in a covered pool  endseq',
#   'startseq people are diving into a swimming pool  endseq'],
#  '1574401950_6bedc0d29b': ['startseq a boy jumps from the top of a blue plastic slide  endseq',
#   'startseq a child jumps over the slide portion of playground equipment shaded by trees  endseq',
#   'startseq a little boy in a striped shirt jumps from a blue slide  endseq',
#   'startseq a little boy is jumping off the top of a slide  endseq',
#   'startseq a young boy jumps on a slide in a backyard  endseq'],
#  '539493431_744eb1abaa': ['startseq a man is playing with a fire baton in the day light  endseq',
#   'startseq a man juggling fire  endseq',
#   'startseq a man stands near a playground  endseq',
#   'startseq man throws flames outside  endseq',
#   'startseq the guy is holding a black stick in front of a playground  endseq'],
#  '3524436870_7670df68e8': ['startseq a brown dog playing with bubbles  endseq',
#   'startseq a brown dog walking across a lawn as bubbles float by  endseq',
#   'startseq a dark brown dog is looking at bubbles while walking on green grass  endseq',
#   'startseq dog catching bubbles on the grass  endseq',
#   'startseq the brown dog is chasing and popping bubbles  endseq'],
#  '2081446176_f97dc76951': ['startseq a guy with a scarf and woven toboggan  endseq',
#   'startseq a man in black and white cap and scarf  endseq',
#   'startseq a man wearing a scarf and knitted hat is smiling  endseq',
#   'startseq a person wearing a hat and scarf looks to the right  endseq',
#   'startseq the man has a poof on top of his woolen hat  endseq'],
#  '2265367960_7928c5642f': ['startseq a boy sitting down smiling for the picture  endseq',
#   'startseq a child holding some shoes  endseq',
#   'startseq a child in blue and wearing a hat smiles  endseq',
#   'startseq a young boy smiling and holding sandals  endseq',
#   'startseq the boy is wearing a hat and holding sandals  endseq'],
#  '460350019_af60511a3b': ['startseq a black dog and a woman in a red shirt playing tug of war  endseq',
#   'startseq a dog is pulling on one end of a rope and a girl is pulling on the other  endseq',
#   'startseq a woman plays tug of war with her black dog in a brown landscape surrounded by trees  endseq',
#   'startseq a woman plays with her rottweiler dog outside  endseq',
#   'startseq a woman and a dog playing outside endseq'],
#  '2976946039_fb9147908d': ['startseq a group of people surf on a very large wave  endseq',
#   'startseq a group of surfers catching a wave endseq',
#   'startseq people surfing and attempting to surf in the ocean on a big wave  endseq',
#   'startseq several people are surfing on a wave in the sea  endseq',
#   'startseq surfers on a huge ocean wave at sunset  endseq'],
#  '2308108566_2cba6bca53': ['startseq a man rides a bike on a dirt path  endseq',
#   'startseq a person biking through the woods  endseq',
#   'startseq a person dirtbikes along a muddy trail  endseq',
#   'startseq dirt bike rider riding down the slope  endseq',
#   'startseq person rides a dirt bike down a dirt hill  endseq'],
#  '3367758711_a8c09607ac': ['startseq there are two women crossing the street in front of two buses  endseq',
#   'startseq two women in headwraps are hurrying past buses  endseq',
#   'startseq two women walk in front of a bus to cross the road  endseq',
#   'startseq two women walk on the street in front of two buses  endseq',
#   'startseq two women with their heads covered crossing the road in front of buses  endseq'],
#  '3666056567_661e25f54c': ['startseq a group of people walk down a city street at night  endseq',
#   'startseq a group of people walking down the street with one on the phone in a green hat  endseq',
#   'startseq four people are walking along a city sidewalk while the one in the green hat talks on a cellphone  endseq',
#   'startseq four people are walking on a sidewalk  endseq',
#   'startseq four people walk down a sidewalk at night endseq'],
#  '3099264059_21653e2536': ['startseq a skateboarder is jumping almost as high as a building  endseq',
#   'startseq a snowboarder jumping off a tall brick building  endseq',
#   'startseq a snowboarder jumps over a pile of snow  endseq',
#   'startseq snowboarder jumps off rail over snowpile  endseq',
#   'startseq the snowboarder is doing a stunt high in the air at night  endseq'],
#  '2988439935_7cea05bc48': ['startseq a man in a red soccer uniform getting ready to kick the ball  endseq',
#   'startseq a man in a red uniform plays in a soccer game  endseq',
#   'startseq a man in a red uniform runs towards a soccer ball on a field  endseq',
#   'startseq a player in a red uniform gets ready to kick the ball during a soccer match as the crowd watches  endseq',
#   'startseq a soccer player in red uniform runs after a soccer ball  endseq'],
#  '241345864_138471c9ea': ['startseq a boy cheerleader has a girl cheerleader on his knee  endseq',
#   'startseq a female cheerleader sits on the knee of a male cheerleader  endseq',
#   'startseq cheerleaders taking a break endseq',
#   'startseq the cheerleader in red and white is sitting on the knee of a man also wearing red and white  endseq',
#   'startseq two cheerleaders are sitting at a football game  endseq'],
#  '3019199755_a984bc21b1': ['startseq a driver is at the wheel of a race car  endseq',
#   'startseq a man inside a red race car gives a thumbs up sign  endseq',
#   'startseq a man is in a red race car while another man is at the back of it  endseq',
#   'startseq a man is smiling whilst sitting inside a red racing car  endseq',
#   'startseq a race car driver smiles and gives the thumbs up before a race  endseq'],
#  '3201594926_cd2009eb13': ['startseq a girl wearing white polka dots and black boots walks and a woman in a blue outfit hurridly walks behind her  endseq',
#   'startseq a hip young woman down the street with a woman in a kimono walks behind her  endseq',
#   'startseq a woman in boots with a big purse walks down the street followed by a woman in blue  endseq',
#   'startseq a woman walks with her big purse  endseq',
#   'startseq women walk down the street  endseq'],
#  '2540751930_d71c7f5622': ['startseq a man and woman walk away from the camera as a redheaded man walks in the other direction  endseq',
#   'startseq pedestrians walk on a sidewalk next to a grassy wooded field  endseq',
#   'startseq people are walking around a park area  endseq',
#   'startseq people meandering around in a grassy area with trees  endseq',
#   'startseq young adults dressed casually walk around in a field  endseq'],
#  '1475046848_831245fc64': ['startseq a blonde woman in blue shorts walks on the beach carrying her shoes  endseq',
#   'startseq a woman in blue shorts is carrying her shoes whilst walking on the beach next to the ocean  endseq',
#   'startseq blond woman with blue shorts walks along beach carrying shoes in one hand  endseq',
#   'startseq woman carrying her shoes on a beach  endseq',
#   'startseq woman in blue shorts walking barefoot on the beach endseq'],
#  '2877637572_641cd29901': ['startseq a cute puppy fetches a yellow ring chew toy in the yard  endseq',
#   'startseq a puppy is running across the grass with a yellow toy in its mouth  endseq',
#   'startseq a tan dog is running through the grass with a yellow toy in its mouth  endseq',
#   'startseq a tan dog with a red collar runs with a yellow toy in its mouth  endseq',
#   'startseq fluffy golden puppy holding yellow rings in mouth while running through grass endseq'],
#  '1308472581_9961782889': ['startseq a boy in blue shirt splashing in water under a dock endseq',
#   'startseq a laughing girl holding a bucket splashes in the ocean endseq',
#   'startseq a young girl plays under a pier with a blue bucket  endseq',
#   'startseq girls with a blue bucket is playing and splashing in the ocean water  endseq',
#   'startseq the girl with the blue bucket splashes beneath the pier  endseq'],
#  '2282260240_55387258de': ['startseq a little girl dances in a room with balloons on the floor  endseq',
#   'startseq a young girl dancing in her socks on a wooden floor strewn with pink balloons  endseq',
#   'startseq child with pink strings on head dancing surrounded by confetti balloons  endseq',
#   'startseq little girl in brown shirt and bluejean skirt dances on wood floor  endseq',
#   'startseq the blond girl is dancing inside a house  endseq'],
#  '2363419943_717e6b119d': ['startseq a lady and her little girl are holding hands and walking up the sidewalk  endseq',
#   'startseq a mother and child run hand in hand through chinatown in an american city  endseq',
#   'startseq a woman and a child both wearing red outfits walking up a street endseq',
#   'startseq child in red holding the hand of person in red coat walking on sidewalk under awnings  endseq',
#   'startseq woman and little girl wearing red in asian area endseq'],
#  '392976422_c8d0514bc3': ['startseq a boy in a blue shirt is walking along a tan and blue wall endseq',
#   'startseq a boy in stripes walking along a ledge  endseq',
#   'startseq a boy scales the wall  endseq',
#   'startseq a child in a striped shirt is walking along a wall  endseq',
#   'startseq boy in striped t shirt walking along a ledge  endseq'],
#  '103205630_682ca7285b': ['startseq a tent is being set up on the ice  endseq',
#   'startseq two men are about to enter an ice fishing tent on a snow covered lake  endseq',
#   'startseq two men setting up a blue ice fishing hut on an iced over lake endseq',
#   'startseq two men standing on an ice looking into something covered with a blue tarp  endseq',
#   'startseq two people standing outside a blue tent structure on a snowy surface  endseq'],
#  '1347519824_e402241e4f': ['startseq a few girls with green foam statue of liberty hats on a train endseq',
#   'startseq some young adults are wearing green foam statute of liberty crowns  endseq',
#   'startseq some young people take photos of each other while in new york  endseq',
#   'startseq three woman with statue of liberty hats and taking a picture  endseq',
#   'startseq two woman wearing statue of liberty hats get their picture taken in a subway  endseq'],
#  '584484388_0eeb36d03d': ['startseq two brown dogs are playing with a red ball  endseq',
#   'startseq two brown dogs fight over a red ball while playing in the grass  endseq',
#   'startseq two brown dogs run over the grass carrying a red toy  endseq',
#   'startseq two daschunds play with a red ball endseq',
#   'startseq two little wiener dogs are running on the grass carrying a red ball between them  endseq'],
#  '2460823604_7f6f786b1c': ['startseq a boy baseball player in a green and yellow jersey leaps for the ball  endseq',
#   'startseq a boy chasing a baseball  endseq',
#   'startseq a little boy playing baseball goes for the ball on the ground  endseq',
#   'startseq a young boy dives to catch the ball during a baseball game  endseq',
#   'startseq the boy in the green and yellow shirt has a glove on and is going towards the ball  endseq'],
#  '121800200_bef08fae5f': ['startseq a group of climbers begin up a sheer rock face  endseq',
#   'startseq a group of rock climbers climb a rock wall in a forest  endseq',
#   'startseq many people are climbing the mountain surrounded by pretty green trees  endseq',
#   'startseq people at a distance trying to climb a cliff  endseq',
#   'startseq the flat side of a large rocky mountain  endseq'],
#  '2422302286_385725e3cf': ['startseq a child sits in a plastic toy car  endseq',
#   'startseq a little kid in a toy car  endseq',
#   'startseq small girl riding in play car  endseq',
#   'startseq there is a child in a red and yellow toy car  endseq',
#   'startseq the small child is sitting in a red and yellow toy car  endseq'],
#  '3183883750_b6acc40397': ['startseq two girls hold up a card reading know what this is  endseq',
#   'startseq two kids smiling and holding a card  endseq',
#   'startseq two people pose for a picure holding a card that says know what this is  endseq',
#   'startseq two people smile at the camera while holding a sign  endseq',
#   'startseq two teenage girls hold a card referring to periods as they smile  endseq'],
#  '3091912922_0d6ebc8f6a': ['startseq a dog runs holding a yellow dog toy in fall bench in the background  endseq',
#   'startseq a dog runs with a yellow toy in its mouth  endseq',
#   'startseq a tan dog running through the grass with a toy in his mouth  endseq',
#   'startseq the brown dog is running through the grass with a yellow toy in its mouth  endseq',
#   'startseq the tan colored dog has a yellow toy in its mouth  endseq'],
#  '2787868417_810985234d': ['startseq a blond girl in a pink bathing suit running through the sprinklers endseq',
#   'startseq a girl in pink runs through a sprinkler  endseq',
#   'startseq a girl runs through sprinklers on a lawn  endseq',
#   'startseq a little girl in pink in running through a sprinkler  endseq',
#   'startseq a little girl wearing a pink dress is running across the grass  endseq'],
#  '3670075789_92ea9a183a': ['startseq a child is sliding into a small pool  endseq',
#   'startseq a girl in a child is swimming pool  endseq',
#   'startseq a little girl is sliding down a short slide into an inflatable paddling pool  endseq',
#   'startseq girl splashing in kiddie pool endseq',
#   'startseq the dark haired girl is sliding into a white kiddie pool  endseq'],
#  '3329169877_175cb16845': ['startseq a lone snowboarder wearing a white jacket jumping into the air on the snowy mountains  endseq',
#   'startseq a snowboarder flies through the air in front of leafless trees  endseq',
#   'startseq a snowboarder gets some air  endseq',
#   'startseq a snowboarder in green pants and a white jacket is jumping high in the air  endseq',
#   'startseq someone in green pants is on a white snowboard in the air  endseq'],
#  '751074141_feafc7b16c': ['startseq a boy being pulled on a shovel  endseq',
#   'startseq a happy child play in the scoop of a shovel by a chair in a grassy backyard  endseq',
#   'startseq a little boy in red flowered shorts is sitting on a shovel  endseq',
#   'startseq a little boy smiling and riding in a shovel  endseq',
#   'startseq small boy in red shorts with blue flowers sitting on shovel in the grass near a tan chair  endseq'],
#  '3445428367_25bafffe75': ['startseq a person is standing on a brick ledge taking a picture of something in the distance  endseq',
#   'startseq a woman takes a photograph  endseq',
#   'startseq a woman with long hair pointing her camera skyward as she stands on a brick wall  endseq',
#   'startseq the woman is holding a camera and standing on a brick wall  endseq',
#   'startseq woman standing on a brick wall and taking a picture endseq'],
#  '3542418447_7c337360d6': ['startseq a black dog and a brown dog with a yellow foam soccer ball toy on a grassy field endseq',
#   'startseq a brown dog and a black dog playing with a yellow soccer ball  endseq',
#   'startseq two dogs on a lawn play with a plastic toy in a distorted photograph  endseq',
#   'startseq two dogs one brown one black with a yellow toy black dog has mouth open and brown dog has the toy  endseq',
#   'startseq two dogs run to catch a yellow soccer ball  endseq'],
#  '2730819220_b58af1119a': ['startseq a little girl ends up at the bottom of the slide  endseq',
#   'startseq a little girl is just reaching the bottom of a playground slide endseq',
#   'startseq a little girl lands at the bottom of a slide  endseq',
#   'startseq a young girl reaches the bottom of a slide  endseq',
#   'startseq a young girl sliding down a tan plastic slide endseq'],
#  '3543378438_47e2712486': ['startseq a man dressed in a green jacket is playing piano while a woman sings  endseq',
#   'startseq a man is sitting in front of a harpsichord and a woman is preparing to sing  endseq',
#   'startseq a person playing the piano with a singer nearby  endseq',
#   'startseq a pianist and a singer are ready to perform  endseq',
#   'startseq the man in the green jacket is playing the piano next to a woman who is by a music stand  endseq'],
#  '2335619125_2e2034f2c3': ['startseq a big black dog bares its teeth while running through the snow  endseq',
#   'startseq a black dog is running through the snow  endseq',
#   'startseq a black dog is running through the snow  endseq',
#   'startseq a black dog with his mouth open and tongue out runs across an expanse of snow  endseq',
#   'startseq black dog runs through snow  endseq'],
#  '3520199925_ca18d0f41e': ['startseq a curly haired woman plays the violin  endseq',
#   'startseq a red haired woman is holding a violin and boe  endseq',
#   'startseq a woman is playing a violin while surrounded by transparent walls and pictures  endseq',
#   'startseq a woman playing the violin with posters in the background  endseq',
#   'startseq the woman is holding a violin  endseq'],
#  '3374722123_6fe6fef449': ['startseq an elderly woman is wearing a pink striped shirt  endseq',
#   'startseq an older woman in a pink striped shirt endseq',
#   'startseq an older woman with a striped shirt rubbing her chin  endseq',
#   'startseq a woman in a pink striped shirt with her hand up  endseq',
#   'startseq older lady is appears to be getting ready to cover her mouth  endseq'],
#  '3280672302_2967177653': ['startseq a boy carries a teenager on his back  endseq',
#   'startseq a boy struggles to carry a girl on his back  endseq',
#   'startseq a person wearing a black shirt is getting a piggy back ride from a person wearing a black t shirt walkng on a paved path in the woods  endseq',
# ...
#   'startseq a dog with a wrinkled face bites on a pink toy  endseq',
#   'startseq a wrinkled dog playing with a pink chew toy endseq',
#   'startseq the dog is carrying a pink ball in its mouth  endseq',
#   'startseq this is a strange sight a dog delivering a cookie  endseq'],
#  '3304712466_18cbdb85fe': ['startseq bicycle racers being cheered on by some people  endseq',
#   'startseq bicycle road racers passing a group of cheering spectators  endseq',
#   'startseq crowds cheer on cyclists as they complete a race to the finish  endseq',
#   'startseq people on bicycles riding through a group of onlookers  endseq',
#   'startseq racers on bikes riding past a crowd  endseq'],
#  '2721656220_5f4cda8bc1': ['startseq a lady holds a beverage  endseq',
#   'startseq an attractive brunette woman smiles and holds a beverage in front of her  endseq',
#   'startseq a woman holding a drink and smiling  endseq',
#   'startseq a woman holds a drink and smiles  endseq',
#   'startseq this woman is wearing a white t shirt and holding a cup  endseq'],
#  '1253275679_e955fb7304': ['startseq a boy has his head down and is wearing a shirt that says adhd  endseq',
#   'startseq a young boy wearing a clever black and white shirt with his head bowed down endseq',
#   'startseq the boy is wearing a black t shirt with an ad parody of the ac logo  endseq',
#   'startseq young boy wearing an ac t shirt looking down  endseq',
#   'startseq young boy with a black adhd t shirt nodding off endseq'],
#  '3668984985_b60ceb2ae9': ['startseq a family sits on a bench in front of a pool  endseq',
#   'startseq a few couples sitting on beanches next to a pool endseq',
#   'startseq a girl wearing boots stands next to a swimming pool and four people seated on a bench  endseq',
#   'startseq a group of people talking next to a pool with trees in the background  endseq',
#   'startseq people sit on a bench by the pool  endseq'],
#  '3241726740_6d256d61ec': ['startseq a man smoking a cigarette talking to a lady who is sitting on steps  endseq',
#   'startseq lady in black standing and smoking with another girl sitting on the steps  endseq',
#   'startseq the person in black smoked while the woman in brown sat on the steps  endseq',
#   'startseq the woman in the black coat is smoking and the woman in the gray coat sits on stone steps  endseq',
#   'startseq two women smoking on the steps of a white building  endseq'],
#  '310213587_778fe8fb5b': ['startseq a group of people sitting on benches at a city park  endseq',
#   'startseq a man drinking a beverage and holding a plastic bag far away from the other people  endseq',
#   'startseq a man drinking a soda is standing in front of a bench near a group of people sitting endseq',
#   'startseq a man in black clothes and a blue hat is taking a drink and holding a shopping bag  endseq',
#   'startseq a man is standing next to a bench drinking a soda while other people sit on a bench nearby  endseq'],
#  '2974501005_346f74e5d8': ['startseq a boy does a skateboard jump at a skateboard park  endseq',
#   'startseq a kid doing a trick on his skateboard  endseq',
#   'startseq a young boy is performing tricks with a skateboard at a skate park  endseq',
#   'startseq a young man rides a yellow and black skateboard at the top of a ramp  endseq',
#   'startseq kid doing skateboard trick with his legs split and board between them  endseq'],
#  '3716277216_c04002be81': ['startseq three african american women are dressed in bright orange and brown dresses and head scarves  endseq',
#   'startseq three african women in traditional orange costume are gathered in front of a yellow curtain  endseq',
#   'startseq three women are dressed in african clothes and two of them are putting on make up  endseq',
#   'startseq three women wearing traditional apparel make the final touches on their clothing  endseq',
#   'startseq women are putting their robes and headdresses on  endseq'],
#  '3320209694_db579cb607': ['startseq a man in a purple had climbs a rocky wall with his hands  endseq',
#   'startseq a man with a purple hat is climbing a rock  endseq',
#   'startseq a man with a purple hat and bandaged hand climbs a wall of rock endseq',
#   'startseq a young man in a purple snow cap is rock climbing  endseq',
#   'startseq this young man is rock climbing endseq'],
#  '3368865171_597d51cdd5': ['startseq a child rides a unicycle while a crowd watches  endseq',
#   'startseq a little girl rides on a bicycle during a parade  endseq',
#   'startseq a small girl riding a unicycle  endseq',
#   'startseq girl in plaid shirt riding a unicycle  endseq',
#   'startseq person in checked shirt riding unicycle while crowd watches  endseq'],
#  '124881487_36e668145d': ['startseq a man on bicycle riding down a rocky hill  endseq',
#   'startseq a man rides his dirt bike down a rocky trail  endseq',
#   'startseq a person rides a bike down a rocky hill  endseq',
#   'startseq blurry picture of mountain biker descending rocky trail  endseq',
#   'startseq the mountain biker in blue rides down a rocky path  endseq'],
#  '2701603045_6cbdc4ce7c': ['startseq a boy is wading through water  endseq',
#   'startseq a boy up to his knees in water  endseq',
#   'startseq a boy wearing white shorts walks through the water  endseq',
#   'startseq a young boy with white swim trunks walks out of the water  endseq',
#   'startseq the boy is wading through the blue ocean  endseq'],
#  '2278766574_f71f1704a8': ['startseq a youn woman on a man is back walking down a cement path with another couple behind them holding hands  endseq',
#   'startseq people walk on a path outside  endseq',
#   'startseq several people are walking down a trail  endseq',
#   'startseq the man is giving a woman a piggyback ride through a park  endseq',
#   'startseq two couples walking on a path adorned with trees bushes and grass  endseq'],
#  '347543966_b2053ae78c': ['startseq a group of men stand outside a glass and steel building  endseq',
#   'startseq three men are looking at a wall very intently in a city  endseq',
#   'startseq three men stand in a glass area  endseq',
#   'startseq three people in a glass structure  endseq',
#   'startseq three people stand in an outdoor glass structure  endseq'],
#  '1143882946_1898d2eeb9': ['startseq a lady wearing a helmet holding a bike  endseq',
#   'startseq a woman in a blue vest and a sky blue helmet stands with her bicycle in traffic  endseq',
#   'startseq a woman in a helmet rides her bike behind a car  endseq',
#   'startseq a woman with a helmet and a backpack walks next to her bike  endseq',
#   'startseq women with bike and helmet wait for traffic  endseq'],
#  '2029280005_a19609c81a': ['startseq a man in a black shirt is rollerblading past a bench in the city  endseq',
#   'startseq a man is inline skating in front of a wooden bench  endseq',
#   'startseq a man is wearing rollerblades standing on a paved area near a park bench  endseq',
#   'startseq a man on rollerblades travelling down the sidewalk  endseq',
#   'startseq a man wearing a black shirt and brown pants skates on a concrete surface near a park bench  endseq'],
#  '3231751379_10ebf7150c': ['startseq a goalie is crouching in a defensive position in front of the goal  endseq',
#   'startseq a hockey player in blue and red guarding the goal  endseq',
#   'startseq an ice hockey goalkeeper in a red and blue strip is on his knees in front of the goal  endseq',
#   'startseq an ice hockey player is bending down on the ice  endseq',
#   'startseq the hockey player knelt on the ice  endseq'],
#  '3069216757_c419b3898e': ['startseq a girl in a pink striped shirt is in front of an armoire  endseq',
#   'startseq a girl in a pink striped shirt poses for the camera  endseq',
#   'startseq a girl wearing a pink striped shirt throws her arms into the air  endseq',
#   'startseq a young girl wearing a pink and orange stripped shirt extends her arms forward and appears to be happy  endseq',
#   'startseq the girl wearing the pink striped shirt is standing in the doorway with her arm outstretched  endseq'],
#  '3234719720_5bb2fc5ffa': ['startseq a dark haired bearded man in a white dress shirt and black sweater and a woman in a black and white dress in a small space  endseq',
#   'startseq a man and women both in black and white are in an elevator  endseq',
#   'startseq a man with a large beard and a woman wearing a white necklace smile  endseq',
#   'startseq a nicely dressed woman and bearded man in a small room  endseq',
#   'startseq a smiling man leaning to his right stands behind a smiling woman leaning to her left  endseq'],
#  '491964988_414b556228': ['startseq a little girl runs down a path in a japanese garden  endseq',
#   'startseq a little girl skips down a path near an idyllic country pond  endseq',
#   'startseq a young girl hops on the path to avoid the puddles located near a lake  endseq',
#   'startseq a young girl is jumping on a gravel road near a pond  endseq',
#   'startseq the girl runs near a pond  endseq'],
#  '2474047296_fd9179d438': ['startseq a man in a white shirt and dress pants sits just underneath a stone archway  endseq',
#   'startseq a man wearing a white shirt and black pants sitting on a staircase endseq',
#   'startseq an old man sits in an ancient brick archway  endseq',
#   'startseq an old man with a white shirt and black pants sits on a chair in the opening of a stone tunnel  endseq',
#   'startseq elderly man sitting in a doorway  endseq'],
#  '3546891929_f31a99cd0d': ['startseq a man in a bicycle helmet is talking on a cellphone with other people behind him  endseq',
#   'startseq a man in a helmet holding a cellphone  endseq',
#   'startseq a man in a plaid shirt with a red and black bike helmet on his cellphone  endseq',
#   'startseq a man wearing a red bicycle helmet talking on a cellphone with other people in the background  endseq',
#   'startseq a man with a bicycle helmet on is using a cellphone in the midst of a crowd  endseq'],
#  '2355763034_9fb61a8165': ['startseq a flautist plays the flute in a marching band endseq',
#   'startseq a girl in a band is playing the flute  endseq',
#   'startseq a girl in a red and black uniform is playing the flute as part of a marching band  endseq',
#   'startseq a woman in a red uniform is playing the flute  endseq',
#   'startseq girl in uniform playing flute with marching band  endseq'],
#  '3065560742_f6e266ccd9': ['startseq a boy playing hockey lies on the ice injured  endseq',
#   'startseq the two hockey players are down on the ice  endseq',
#   'startseq two hockey players fall on the ice  endseq',
#   'startseq two hockey players fall to the ground in a game  endseq',
#   'startseq two hockey players slide into each other on the ice endseq'],
#  '265528702_8653eab9fa': ['startseq a man in sunglasses and a neatly trimmed beard overlooks a woody valley  endseq',
#   'startseq a man posing with large grassy mountains off in the distance  endseq',
#   'startseq a man wearing sunglasses stands before a forested landscape  endseq',
#   'startseq a man with a beard and sunglasses is standing in front of tree covered hills  endseq',
#   'startseq bearded man with sunglasses in the mountains  endseq'],
#  '2687539673_d54a8dc613': ['startseq a girl and young boy are jumping on a trampoline in a suburban yard  endseq',
#   'startseq a girl is jumping on a trampoline with her arms in the air while a boy in a blue shirt is bouncing on his stomach  endseq',
#   'startseq a teenager girl jumps high on a trampoline and a toddler falls on his stomach  endseq',
#   'startseq a toddler and a teenage girl jumping on a trampoline  endseq',
#   'startseq two children jump on a trampoline  endseq'],
#  '3067500667_0fce8f28d4': ['startseq a cricket batsman has been bowled out middle stump  endseq',
#   'startseq a cricket player swings his bat but misses  endseq',
#   'startseq a man is standing in front of some red sticks trying to hit a ball  endseq',
#   'startseq a man is swinging a paddle at a unique ball game  endseq',
#   'startseq a player hits the ball at a cricket game  endseq'],
#  '2657484970_610e18144f': ['startseq people are boating near a mountain  endseq',
#   'startseq two people in a canoe are rowing past a large tree covered mountain  endseq',
#   'startseq two people in a canoe float past a rocky wooded cliff  endseq',
#   'startseq two people in a canoe on a river beside a forested mountain  endseq',
#   'startseq two people in a kayak are paddling past green foliage on a river  endseq'],
#  '407008823_bdd7fc6ed5': ['startseq a climber is making his way up a snowy mountainside  endseq',
#   'startseq a lone person jumping through the air from one snowy mountain to another  endseq',
#   'startseq a man doing tricks in the snow  endseq',
#   'startseq a man dressed in snow gear takes a leap into a snow covered ravine  endseq',
#   'startseq people jump over a mountain crevasse on a rope  endseq'],
#  '3675825945_96b2916959': ['startseq a man in skateboarding in an empty swimming pool  endseq',
#   'startseq a man rides a skateboard up the side of an empty pool  endseq',
#   'startseq a skateboarder dressed in white is dropping into a blue bowl  endseq',
#   'startseq a skateboarder hanging off the edge of a bowl at a skate park  endseq',
#   'startseq a skateboarder in an empty pool  endseq'],
#  '1557838421_a33f2a4911': ['startseq a grey and white dog is biting the ear of a white and brown dog  endseq',
#   'startseq the brown and white dog nips at the yellow dog  endseq',
#   'startseq there are two dogs playing with each other  endseq',
#   'startseq two dogs wrestle with each other with their teeth bared  endseq',
#   'startseq two large dogs attempt to bite each other playfully  endseq'],
#  '544301311_5e7d69a517': ['startseq the women sit outside on the steps reading and drinking  endseq',
#   'startseq two girls sit by a doorway on the steps  endseq',
#   'startseq two women in period dress sitting in a doorway  endseq',
#   'startseq two women in traditional european dress sit on a stoop one drinking the other reading  endseq',
#   'startseq two women with white head garb and long dresses sitting in front of a door on steps reading and drinking a beverage  endseq'],
#  '3624076529_9793655a21': ['startseq a brown dog swimming through a lake with a stick in his mouth  endseq',
#   'startseq a brown dog swimming with a stick  endseq',
#   'startseq a dog holding a stick swims in the water  endseq',
#   'startseq a dog swimming with a stick in its mouth  endseq',
#   'startseq a golden dog swims with a stick in its mouth endseq'],
#  '537479916_c033897fac': ['startseq a black dog finishes running down a blue and orange ramp  endseq',
#   'startseq a black dog has just run down a blue and red ramp on an obstacle course  endseq',
#   'startseq a dog and person doing an agility course  endseq',
#   'startseq a dog runs dog a ramp  endseq',
#   'startseq a dog runs down a ramp past its trainer  endseq'],
#  '2737729252_b3fd9c05b1': ['startseq a girl is taking a picture of another girl in a park  endseq',
#   'startseq a girl is taking a picture of another girl in a park  endseq',
#   'startseq a woman takes a picture of another in purple in a park  endseq',
#   'startseq one girl taking a picture of her friend endseq',
#   'startseq two little girls playing in the parking lot  endseq'],
#  '267162122_c3437414ec': ['startseq a black puppy jumping on the back of a white puppy endseq',
#   'startseq a black dog and a white dog wrestle  endseq',
#   'startseq a black dog and a white dog wrestling next to a food dish  endseq',
#   'startseq a black puppy stands over a white puppy  endseq',
#   'startseq a small black dog is standing over a small white dog laying on his side  endseq'],
#  '2592711202_55f8c64495': ['startseq a girl dressed in blue enjoys a blue treat while putting her white shoe back on  endseq',
#   'startseq a girl in a blue dress sitting on the ground eating cotton candy  endseq',
#   'startseq a girl in a blue dress takes off her shoes and eats blue cotton candy  endseq',
#   'startseq child in blue dress holding sandal in one hand and eating blue cotton candy with other hand  endseq',
#   'startseq the girl in a blue dress is eating some blue cotton candy with one shoe off and one shoe on  endseq'],
#  ...}

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils.np_utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
caption_list = []
for el in train_descriptions.values():
    for ec in el:
        caption_list.append(ec)
print("The total caption present = {}".format(len(caption_list)))
# Out:
# The total caption present = 30000

# %%
token = Tokenizer(num_words=VOCAB_SIZE)
token.fit_on_texts(caption_list)

# %% [markdown]
# 1. **Caution**: tokenizer considers only top words provided by num_words while converting to sequences. i.e. if word is not present the it skips the word.
# 2. But toke.index_word keeps all the record of words in whole vocabulary.So, remoove unnecessary words while using token.index_words as a dictionary.

# %%
# index to words are assigned according to frequency. i.e the most frequent word has index of 1
ix_to_word = token.index_word

# %%
for k in list(ix_to_word):
    if k>=1665:
        ix_to_word.pop(k, None)

# %%
word_to_ix = dict()
for k,v in ix_to_word.items():
    word_to_ix[v] = k

# %%
print(len(word_to_ix))
print(len(ix_to_word))
# Out:
# 1664
# 1664

# %%
# finding the max_length caption
MAX_LENGTH = 0
temp = 0
for ec in caption_list:
    temp = len(ec.split())
    if(MAX_LENGTH<=temp):
        MAX_LENGTH = temp

# %%
print("Maximum caption has length of {}".format(MAX_LENGTH))
# Out:
# Maximum caption has length of 39

# %%
# please refer https://towardsdatascience.com/image-captioning-with-keras-teaching-computers-to-describe-pictures-c88a46a311b8
# data generator, intended to be used in a call to model.fit_generator()

def data_generator(descriptions, photos, MAX_LENGTH,VOCAB_SIZE, num_photos_per_batch):
    X1, X2, y = list(), list(), list()
    n=0
    # loop for ever over images
    while 1:
        for key, desc_list in train_descriptions.items():
            n+=1
            # retrieve the photo feature
            photo = photos[key]
            for desc in desc_list:
                seq = token.texts_to_sequences([desc])
                seq = seq[0]
                for i in range(1,len(seq)):
                    in_seq , op_seq = seq[:i],seq[i]
                    #converting input sequence to fix length
                    in_seq = pad_sequences([in_seq],maxlen=MAX_LENGTH,padding="post")[0]
                    # converting op_seq to vocabulary size
                    op_seq = to_categorical([op_seq],num_classes=VOCAB_SIZE)[0]
                    X1.append(photo)
                    X2.append(in_seq)
                    y.append(op_seq)
            # yield the batch data
            if n==num_photos_per_batch:
                yield [[array(X1), array(X2)], array(y)]
                X1, X2, y = list(), list(), list()
                n=0

# %% [markdown]
# 1. We are using glove_vector file for word embedding as it is already avaialable with us.
# 2. Each sequence will be encoded [34] ==> [34x300]
# 3. For words which are not in glove_vector we are setting the vector to zero

# %%
# make sure you have the glove_vectors file
with open('glove_vectors', 'rb') as f:
    glove = load(f)
    glove_words =  set(glove.keys())

# %%
EMBEDDING_SIZE = 300

# Get 300-dim dense vector for each of the words in vocabulary
embedding_matrix = np.zeros((VOCAB_SIZE,EMBEDDING_SIZE))
embedding_matrix.shape
# Out:
# (1665, 300)

# %%
EMBEDDING_SIZE = 300

# Get 300-dim dense vector for each of the words in vocabulary
embedding_matrix = np.zeros(((VOCAB_SIZE),EMBEDDING_SIZE))

for word, i in word_to_ix.items():
    embedding_vector = np.zeros(300)
    if word in glove_words:
        embedding_vector = glove[word]
        embedding_matrix[i] = embedding_vector
    else:
        # Words not found in the embedding index will be all zeros
        embedding_matrix[i] = embedding_vector

# %%
# save the embedding matrix to file
with open("embedding_matrix.pkl","wb") as f:
    dump(embedding_matrix,f)

# %%
embedding_matrix.shape
# Out:
# (1665, 300)

# %%
# save the tokenizer to file
with open("token.pkl","wb") as f:
    dump(token,f)

# %% [markdown]
# **Training the model**

# %%
# load image feature extracted file
with open("train_image_extracted.pkl","rb") as f:
    train_image_extracted = load(f)

# %%
# reload model saved in final model ipynb
#https://stackoverflow.com/questions/42763094/how-to-save-final-model-using-keras

from keras.models import model_from_json
from keras.models import load_model

# %%
with open("model.json","r") as f:
    model = model_from_json(f.read())

print("Model loaded successfully")
# Out:
# Model loaded successfully

# %%
# loading the weights of the model
model.load_weights("model_weights/model_19.h5")

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 39)           0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 2048)         0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 39, 300)      499500      input_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 2048)         0           input_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 39, 300)      0           embedding_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 300)          614700      dropout_2[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 300)          721200      dropout_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 300)          0           dense_1[0][0]
#                                                                  lstm_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 300)          90300       add_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1665)         501165      dense_2[0][0]
# ==================================================================================================
# Total params: 2,426,865
# Trainable params: 1,927,365
# Non-trainable params: 499,500
# __________________________________________________________________________________________________

# %% [markdown]
# Total Epochs = 30
#
# For 1st 20 epoch , batch size = 5 images ====> stpes per epoch = 1200

# %%
epochs = 20
batch_size = number_pics_per_bath = 5
steps = len(train_descriptions)//number_pics_per_bath

# %%
len(train_descriptions)

# %%
for i in range(epochs):
    if epochs<11:
    generator = data_generator(train_descriptions,train_image_extracted,MAX_LENGTH,VOCAB_SIZE,number_pics_per_bath)
    model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
    model.save('model_weights/model_demo' + str(i) + '.h5')
# Out:
# Epoch 1/1
# 600/600 [==============================] - 422s 704ms/step - loss: 3.9709
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-cbc551cff41a> in <module>
#       2     generator = data_generator(train_descriptions,train_image_extracted,MAX_LENGTH,VOCAB_SIZE,number_pics_per_bath)
#       3     model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
# ----> 4     model.save('model_weights/model_demo' + str(i) + '.h5')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\network.py in save(self, filepath, overwrite, include_optimizer)
#    1088             raise NotImplementedError
#    1089         from ..models import save_model
# -> 1090         save_model(self, filepath, overwrite, include_optimizer)
#    1091
#    1092     def save_weights(self, filepath, overwrite=True):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     380
#     381     try:
# --> 382         _serialize_model(model, f, include_optimizer)
#     383     finally:
#     384         if opened_new_file:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\saving.py in _serialize_model(model, f, include_optimizer)
#     130                 'optimizer_config': {
#     131                     'class_name': model.optimizer.__class__.__name__,
# --> 132                     'config': model.optimizer.get_config()
#     133                 },
#     134                 'loss': model.loss,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\optimizers.py in get_config(self)
#     515
#     516     def get_config(self):
# --> 517         config = {'lr': float(K.get_value(self.lr)),
#     518                   'beta_1': float(K.get_value(self.beta_1)),
#     519                   'beta_2': float(K.get_value(self.beta_2)),
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in get_value(x)
#    2405         A Numpy array.
#    2406     """
# -> 2407     return x.eval(session=get_session())
#    2408
#    2409
#
# AttributeError: 'float' object has no attribute 'eval'

# %% [markdown]
# For last 10 epochs,
#
# modifying learning rate to 0.0001 and batch size = 10 , steps per epoch = 600

# %%
batch_size = number_pics_per_bath = 10
steps = len(train_descriptions)//number_pics_per_bath
epochs = 10
# modifying learning rate to 0.0001
#https://towardsdatascience.com/image-captioning-with-keras-teaching-computers-to-describe-pictures-c88a46a311b8
model.optimizer.lr = 0.0001

# %%
for i in range(epochs):
    generator = data_generator(train_descriptions,train_image_extracted,MAX_LENGTH,VOCAB_SIZE,number_pics_per_bath)
    model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
# Out:
# Epoch 1/1
# 600/600 [==============================] - 442s 737ms/step - loss: 2.0805
# Epoch 1/1
# 600/600 [==============================] - 433s 722ms/step - loss: 2.0330
# Epoch 1/1
# 600/600 [==============================] - 432s 719ms/step - loss: 2.0105
# Epoch 1/1
# 600/600 [==============================] - 425s 708ms/step - loss: 1.9965
# Epoch 1/1
# 600/600 [==============================] - 431s 718ms/step - loss: 1.9817
# Epoch 1/1
# 600/600 [==============================] - 440s 733ms/step - loss: 1.9676
# Epoch 1/1
# 600/600 [==============================] - 453s 755ms/step - loss: 1.9560
# Epoch 1/1
# 600/600 [==============================] - 447s 745ms/step - loss: 1.9448
# Epoch 1/1
# 600/600 [==============================] - 442s 737ms/step - loss: 1.9335
# Epoch 1/1
# 600/600 [==============================] - 463s 771ms/step - loss: 1.9236

# %%
model.save_weights('model_weights/model_final.h5')
